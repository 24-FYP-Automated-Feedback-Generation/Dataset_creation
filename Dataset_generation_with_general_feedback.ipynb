# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = "/content/drive/MyDrive/dataset_general feedback.csv"
df = pd.read_csv(file_path, encoding='latin-1')
# Out:
# <ipython-input-5-c403edfdb41b>:2: DtypeWarning: Columns (2,3,4,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='latin-1')

# %%
df.head()
# Out:
#        pid  sid                                       student_code  \
# 0  17311.0  1.0  """ store the final answer in a variable named...
# 1  17312.0  2.0  """ store the final answer in a variable named...
# 2  17312.0  3.0  """ store the final answer in a variable named...
# 3  17312.0  4.0  x=eval(input("Enter your age:"))\ny=str(input(...
# 4  17312.0  5.0  n = str(input("Enter your name:"))\na = str(in...
#
#                                        repaired_code  \
# 0  """ store the final answer in a variable named...
# 1  """ store the final answer in a variable named...
# 2  """ store the final answer in a variable named...
# 3  y = input("Enter your name:")\nx = eval(input(...
# 4  n = str(input("Enter your name:"))\na = str(in...
#
#                                             feedback  num_iteration  \
# 0  [\n    {\n    'line_number': 2,\n    'feedback...            1.0
# 1  [\n    {\n        'line_number': 4,\n        '...            1.0
# ...

# %%
df = df[['sid','student_code', 'repaired_code', 'feedback']]

# %%
df.head()
# Out:
#    sid                                       student_code  \
# 0  1.0  """ store the final answer in a variable named...
# 1  2.0  """ store the final answer in a variable named...
# 2  3.0  """ store the final answer in a variable named...
# 3  4.0  x=eval(input("Enter your age:"))\ny=str(input(...
# 4  5.0  n = str(input("Enter your name:"))\na = str(in...
#
#                                        repaired_code  \
# 0  """ store the final answer in a variable named...
# 1  """ store the final answer in a variable named...
# 2  """ store the final answer in a variable named...
# 3  y = input("Enter your name:")\nx = eval(input(...
# 4  n = str(input("Enter your name:"))\na = str(in...
#
#                                             feedback
# 0  [\n    {\n    'line_number': 2,\n    'feedback...
# 1  [\n    {\n        'line_number': 4,\n        '...
# 2  [\n    {\n        'line_number': 2,\n        '...
# 3  [\n    {\n        'line_number': 1,\n        '...
# ...

# %%
# Generate a new column with random 1x16 vectors (values 1, 2, or 3)
df['metacognitive_vector'] = [list(np.random.randint(1, 4, 16)) for _ in range(len(df))]

# %%
df.head()
# Out:
#    sid                                       student_code  \
# 0  1.0  """ store the final answer in a variable named...
# 1  2.0  """ store the final answer in a variable named...
# 2  3.0  """ store the final answer in a variable named...
# 3  4.0  x=eval(input("Enter your age:"))\ny=str(input(...
# 4  5.0  n = str(input("Enter your name:"))\na = str(in...
#
#                                        repaired_code  \
# 0  """ store the final answer in a variable named...
# 1  """ store the final answer in a variable named...
# 2  """ store the final answer in a variable named...
# 3  y = input("Enter your name:")\nx = eval(input(...
# 4  n = str(input("Enter your name:"))\na = str(in...
#
#                                             feedback  \
# 0  [\n    {\n    'line_number': 2,\n    'feedback...
# 1  [\n    {\n        'line_number': 4,\n        '...
# 2  [\n    {\n        'line_number': 2,\n        '...
# 3  [\n    {\n        'line_number': 1,\n        '...
# ...

# %%
# Save the modified dataset to a new CSV file
df.to_csv("modified_dataset.csv", index=False)

# %%
# !pip install optimum[gptq]
# Out:
# ...
# WARNING: optimum 1.23.3 does not provide the extra 'gptq'
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 9.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 424.1/424.1 kB 34.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 14.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 16.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ...

# %%
# !pip install auto-gptq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 70.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 86.9 MB/s eta 0:00:00
# ...

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-generation", model="TheBloke/Nous-Hermes-Llama2-GPTQ")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# WARNING:auto_gptq.nn_modules.qlinear.qlinear_cuda:CUDA extension not installed.
# WARNING:auto_gptq.nn_modules.qlinear.qlinear_cuda_old:CUDA extension not installed.
# `low_cpu_mem_usage` was None, now set to True since model is quantized.
# model.safetensors:   0%|          | 0.00/7.26G [00:00<?, ?B/s]
# ...

# %%
# !pip install --upgrade optimum[gptq]
# !pip install --upgrade auto-gptq
# Out:
# ...
# WARNING: optimum 1.23.3 does not provide the extra 'gptq'
# ...
